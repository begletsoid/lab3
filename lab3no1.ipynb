# %%
import torch
import math
import numpy as np

def grad1(w, x):
    w.requires_grad_(True)
    
    f = 1/(1+torch.exp(-torch.dot(w,x)))
    f.backward()
    return w.grad
grad1(torch.tensor([1.,1.,1.]), torch.tensor([1.,2.,3.]))
